# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavin-Bhesaniya/Python_Example_Colab/blob/main/Python_DataTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Datatype :-
'''
 - Use datatype name constructor for initialize value
  String        " " or """ """      
  int           0,1,-1
  float         1.1,-1.1
  complex       5j
  boolean       True,False
  list          [multi-value] Ex :- ["list","types",1,2.2]
  tuple         (multi-value)       ("tuple",1,2.2)
  dic           {key:value}         {"first" : "dictionary",2 : "second"}
  set           {multi-value}       {"set","type",1} 
'''

# %%
# String - Sequence of character | Immutable |
a = str("String  Datatype")  # Use str constructor
A = "We check THIS String"   # Normal Write

# Access String -
print(a)
print("Access Single Character ", A[0])
print(len(a))   # Find Length of string 
# print("\nAccess Through Loops : ")
# for X in A:
#     print(X)


# Boolean value return while find method return index
print("\nChecking String With Identity Operator : ")
if "S" in a:     
    print("Yes S in a\n")
if a is A:
    print("Yes Both Are Same\n")
else:
    print("No Both Are Not Same\n")


# Slicing -
print("\nSlicing in String :- ")
print(a[0:5])   # Start : end string
print(a[:5])
print(a[-5:])   # Negative index start from -1
print(a[::-1])  # Reverse string


# Update - Immutable so can't change single value | To change either entire or by typecasting
print("\nUpdate String :- ")
A = "Update Entire String"
print(A)


# Delete String -
print("\nDelete String :- ")
deleteStr = "String is delete"
del deleteStr


Q = A.count("S"); print("Total Character in string : ", Q)
S = A.join(a);    print("Join Two String in New string : ", S)


# String Method :-
print("\nString Method :- ")
print("Convert in uppercase : ", a.upper())
print("Convert in lowercase : ", a.lower())
print("Add Symbol at center : ", a.center(10, "#"))
print("Convert into lower : ",   a.casefold())
print("Convert Whitespace to split ", a.split(" "))
print("Fill Space From left with 0 : ", a.zfill(20))
print("Convert First Word in Capital : ", a.title())
print("Remove whitespace begin and end : ", a.strip())
print("OLD value, Replace with new value : ", a.replace("String ", "STRING"))
print("First Character each word is capital : ", a.capitalize())
print("Check Where Word found in string : ", a.index("Str"))
print("Replace each character with given character : ", a.translate("S"))
print("Check String Start With or End with Given Character if yes return 1 otherwise 0 : ", a.startswith("hello"), a.endswith("datatype"))
print("Concat two string : First - " + a + " Second - " + A)
print("Encoding character : ", a.encode(encoding="ascii", errors="ignore"))




'''
 More Method -
  expandtabs | isalpha | isdecimal | isdigit | isidentifier | islower | isnumeric | isprintable | isspace 
  istitle    | supper  | rfind     | rjust   | rsplit       | rstrip 
'''


# String Formatting -
print("\nString Formatting :- f'{variable}' ")
A1 = 10
A2 = "How Old You Are. I {} Old"  # IN CURLY BRACKET VALUE ADD WHICH PASS IN FORMAT
print(A2.format(A1))

A3 = "FIRST {1} VALUE ADD.SECOND {0} VALUE"  # Index in multiple value / {:.2f} for float
print(A3.format(A1, A2))

A4 = "HERE WE YOU KEYWORD ARGUMENT {first}. WE PASS KEYWORD IN BRACKET {second}"
print(A4.format(first="A1", second="A2"))

txt = "For only {price:.2f} dollars!"
print(txt.format(price=49))

txt1 = "My name is {fname}, I'm {age}"  # .format(fname = "John", age = 36)
print(txt1.format(fname="bhavin", age=21))

txt2 = "My name is {0}, I'm {1}".format("John", 36)
txt3 = "My name is {}, I'm {}".format("John", 36)
# Out:
# String  Datatype
# Access Single Character  W
# 16
#
# Checking String With Identity Operator :
# Yes S in a
#
# No Both Are Not Same
#
#
# Slicing in String :-
# Strin
# Strin
# atype
# epytataD  gnirtS
#
# Update String :-
# Update Entire String
#
# Delete String :-
# Total Character in string :  1
# Join Two String in New string :  SUpdate Entire StringtUpdate Entire StringrUpdate Entire StringiUpdate Entire StringnUpdate Entire StringgUpdate Entire String Update Entire String Update Entire StringDUpdate Entire StringaUpdate Entire StringtUpdate Entire StringaUpdate Entire StringtUpdate Entire StringyUpdate Entire StringpUpdate Entire Stringe
#
# String Method :-
# Convert in uppercase :  STRING  DATATYPE
# Convert in lowercase :  string  datatype
# Add Symbol at center :  String  Datatype
# Convert into lower :  string  datatype
# Convert Whitespace to split  ['String', '', 'Datatype']
# Fill Space From left with 0 :  0000String  Datatype
# ...

# %%
# LIST

# List creation -
print("\nCreate List :- ")
list_var = ["list", 1, 2.2, True]
list_con = list("Use constructor")
print(list_var)
print(list_con)

# Access List :-
print("\nAccessing list and slice - \n",
      list_var[0], "\n",   list_var[-1], "\n",
      list_var[0:3], "\n", list_var[0:], "\n", list_var[:-1], "\n")
print("Access Through for loop : ")
for i in list_var:
    print(i)


# Comprehension :-
# print("\nComprehension Loops List :- ")
# n_list = [x for x in list_var if "i" in x]  # int can't iterable only list,tuple,set
# print(n_list)


# Modify list -
print("\nModify list :- ")
change_list = ["Second List", 1, 2.2, True]
change_list[0] = "THIS"
print("\nUpdate List Value : ", change_list)


# Add value :-
print("\nAdding Value in list :- ")
change_list.insert(0, "insert value")
sec_list = ["second list"]
change_list.append(sec_list)  # Append add item at last | Use any iterable in append

list_var.extend(change_list)
print(change_list, "\n", list_var)


# Remove value -
print("\nRemove Value From List :- ")
change_list.pop(2)        # Without index remove from last
change_list.remove(2.2)   # Remove element with specific value
print(change_list)


# Copy list -
print("\nCopy list :- ")
cp_list = change_list.copy()
print("\nCopy List :", cp_list)


# Sort list :-
print("\nSorting list value :- ")
SortList = [10, 2, 4, 5, 3]
SortList.sort()
print("Sorted List :", SortList)

SortList.sort(reverse=True)
revList = SortList.reverse()
print("Sorted List In Reverse :", revList)


# Find elements in list :-
print("\nFind elements in list :- ")
xc = SortList.count(10)
print("Return 1 if item available :", xc)


xc = SortList.index(10)
print("Return index no where find :", xc)

# Clearlist :-
change_list.clear()
print("Clear entire list", change_list)


# delete list completely
del change_list  # After print generate error
# Out:
# Create List :-
# ['list', 1, 2.2, True]
# ['U', 's', 'e', ' ', 'c', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'o', 'r']
#
# Accessing list and slice -
#  list
#  True
#  ['list', 1, 2.2]
#  ['list', 1, 2.2, True]
#  ['list', 1, 2.2]
#
# Access Through for loop :
# list
# 1
# 2.2
# True
#
# Modify list :-
#
# Update List Value :  ['THIS', 1, 2.2, True]
#
# Adding Value in list :-
# ['insert value', 'THIS', 1, 2.2, True, ['second list']]
#  ['list', 1, 2.2, True, 'insert value', 'THIS', 1, 2.2, True, ['second list']]
#
# Remove Value From List :-
# ['insert value', 'THIS', True, ['second list']]
#
# Copy list :-
#
# Copy List : ['insert value', 'THIS', True, ['second list']]
#
# Sorting list value :-
# Sorted List : [2, 3, 4, 5, 10]
# Sorted List In Reverse : None
#
# Find elements in list :-
# Return 1 if item available : 1
# Return index no where find : 4
# Clear entire list []

# %%
# Create new Tuple
Tup1 = ("THIS", "is", "First", "TuPle")     # Simple tuple
Tup2 = ("THIS", "is", "Mix", 1, 2.2, True)  # Tuple with multi-value
Tup3 = tuple(("Using constructor",))        # Constructor / 0for single value use at end

# Access Value -
print("\nAccessing Value in Tuple :\n", Tup1[0] + " " + Tup1[-1])
print("\nAccessing Value in Tuple Using For Loop :")
for x in Tup1:  # for i in range(len(Tup1)):
    print(x)

# Slice -
print("\nSlicing in Tuple :")
print(Tup1[0:2])
print(Tup1[-1:])
print(Tup1[::-1])

# Change value - Tuple immutable so first change in list than convert
print("\nChange Value Using Type Casting :")
x = list(Tup1)
x[1] = "Is"
x.append("Using list method")
Tup1 = tuple(x)
print(Tup1)

# Unpacking - Assign value to tuple packing | Extract values back into variable unpacking
print("\nUnpacking used :")
fruits = ("apple", "banana", "cherry", "apple", "strawberry", "raspberry")  # Packing
(green, *yellow, red) = fruits  # If no how many value use * at last name   # Unpacking
print("\nUnpacking Values Using Index :", green)
print(yellow)
print(red, "\n")

# Method -
print("Return Item Index No :   ", Tup1.index("First"))
print("Return 1 If Item Found : ", Tup1.count("THIS"))

# Joining Tuple -
tup2 = (2,)
tup3 = Tup1 + tup2
print(tup3)
tup3 = tup2 * 2
print(tup3)

# delete tuple
del Tup1
# Out:
# Accessing Value in Tuple :
#  THIS TuPle
#
# Accessing Value in Tuple Using For Loop :
# THIS
# is
# First
# TuPle
#
# Slicing in Tuple :
# ('THIS', 'is')
# ('TuPle',)
# ('TuPle', 'First', 'is', 'THIS')
#
# Change Value Using Type Casting :
# ('THIS', 'Is', 'First', 'TuPle', 'Using list method')
#
# Unpacking used :
#
# Unpacking Values Using Index : apple
# ['banana', 'cherry', 'apple', 'strawberry']
# raspberry
#
# Return Item Index No :    2
# Return 1 If Item Found :  1
# ('THIS', 'Is', 'First', 'TuPle', 'Using list method', 2)
# (2, 2)

# %%
# Set is unordered and unindexed
set1 = {"Apple", "Hello", "THIS", "is"}
set2 = {"THIS", "is", "A", "Set", 1, 2.3, True}
set3 = set("Using constructor")

# Access list :-
print("\nAccess Set Using :")
print(set1)
print("\nThrough For Loop : ")
for A in set2:
    print(A)
# print(set2[6]) # Unindexed so this generates error


# Add, join ,Copy Values -
print("\nAdd Value, Join, Copy Values : ")
set1.add("Add new item")
set1.update(set2)  # Add Any Iterable With Update Method
print("Set after Update Method :\n", set1)
set4 = set1.union(set3)  # Create new set using union
print("\nUnion set operations :\n", set4)
seCpy = set1.copy()  # Create new set using existing set
print("\nCopy Method :\n", seCpy)

# DIFFERENT SET OPERATION IN SET
print("\nDifference Set Operation :\n")
set1.intersection_update(set2)  # Return common value
print("Return Common Value :\n", set1)
z = set1.intersection(set2)  # Return common value with new set
print("Return Common Value With New Set :\n", z)

sf = {"set", "method", "check", 1}
sf2 = {"set", "method", "check", 1}
sf3 = sf.difference(sf2)
print("Print Difference Value :\n", sf3)
sf3 = sf.difference_update(sf2)
print(sf3)
sf3 = sf.isdisjoint(sf2)
print(sf3)
sf3 = sf.issubset(sf2)
print("True if both set same value :\n", sf3)
sf3 = sf.issuperset(sf2)
print(sf3)


# Remove value :-
print("\nRemove Value From Set : ")
set1.remove("A")   # Remove specific value if not generate error
set1.discard("A")  # Remove specific value if not than not generate error
set1.pop()         # Remove any value
print(set1)
set1.clear()
print("Clear list : ", set1)
del set1
# Out:
# Access Set Using :
# {'Hello', 'THIS', 'Apple', 'is'}
#
# Through For Loop :
# Set
# 1
# 2.3
# THIS
# is
# A
#
# Add Value, Join, Copy Values :
# Set after Update Method :
#  {1, 2.3, 'THIS', 'Hello', 'Apple', 'Add new item', 'Set', 'is', 'A'}
#
# Union set operations :
#  {'t', 1, 2.3, 'THIS', 'Add new item', 'Set', 'c', 'is', 'g', 'r', 'o', 'A', 'n', 'i', 'Hello', 'Apple', 'u', 'U', ' ', 's'}
#
# Copy Method :
#  {1, 2.3, 'THIS', 'Hello', 'Apple', 'Add new item', 'Set', 'is', 'A'}
#
# Difference Set Operation :
#
# Return Common Value :
#  {1, 2.3, 'THIS', 'Set', 'is', 'A'}
# Return Common Value With New Set :
#  {1, 2.3, 'THIS', 'Set', 'is', 'A'}
# Print Difference Value :
#  set()
# None
# True
# True if both set same value :
#  True
# False
#
# Remove Value From Set :
# {2.3, 'THIS', 'Set', 'is'}
# Clear list :  set()

# %%
# Dictionary :- Store values in key:pairs
# Create dictionary :-
Dict = {"First": "Bhavin",
        "Second": "Bhesaniya",
        3: "Number",
        4: 2001,
        "Five": ["Adding", "list", "Add any iterable"]
        }

Dict2 = dict(hello="working")  # Using dict constructor
NestDict = {"first-dict": {"1dictkey": "value",
                           2: "Two"},
            "Secondict": {"2dictkey": "value",
                          2: "second"}}


# Access dictionary :-
print("Accessing dictionary Using Key : " + Dict["First"])
print("\nAccessing dictionary Using get function :- ", Dict.get("Five"))
print("\nGet All Keys :- " , Dict.keys())
print("\nGet All Values :- ", Dict.values())
print("\nGet All keys and Values :- ", Dict.items())   

print("\nAccess dictionary using for loop :- ")
for x in Dict:           # value() | items() | keys() | for i,f in Dict.items():
    print(x, "\t", Dict[x])


# Change dictionary :-
print("\nChanges in dictionary through values or add value :-  ")
Dict[3] = "8989"
Dict.update({4: 1152001})
print(Dict)
# .copy() from exit dict / dict(exit dictionary)


# Method :-
print("\n Extra Method :- ")
thisdict = dict.fromkeys(Dict, Dict2)  # from 1 dict key and another dict value
print(thisdict)
print(Dict.setdefault("First"))  # Default value set

# Remove dictionary :-
print("\nRemove or delete items from dict :- ")
print(Dict.pop(3))      # Remove specific key values
print(Dict.popitem())   # Remove last value
del Dict[4]             # Delete item with specified key
Dict.clear()
print(Dict)
del Dict
# Out:
# Accessing dictionary Using Key : Bhavin
#
# Accessing dictionary Using get function :-  ['Adding', 'list', 'Add any iterable']
#
# Get All Keys :-  dict_keys(['First', 'Second', 3, 4, 'Five'])
#
# Get All Values :-  dict_values(['Bhavin', 'Bhesaniya', 'Number', 2001, ['Adding', 'list', 'Add any iterable']])
#
# Get All keys and Values :-  dict_items([('First', 'Bhavin'), ('Second', 'Bhesaniya'), (3, 'Number'), (4, 2001), ('Five', ['Adding', 'list', 'Add any iterable'])])
#
# Access dictionary using for loop :-
# First 	 Bhavin
# Second 	 Bhesaniya
# 3 	 Number
# 4 	 2001
# Five 	 ['Adding', 'list', 'Add any iterable']
#
# Changes in dictionary through values or add value :-
# {'First': 'Bhavin', 'Second': 'Bhesaniya', 3: '8989', 4: 1152001, 'Five': ['Adding', 'list', 'Add any iterable']}
#
#  Extra Method :-
# {'First': {'hello': 'working'}, 'Second': {'hello': 'working'}, 3: {'hello': 'working'}, 4: {'hello': 'working'}, 'Five': {'hello': 'working'}}
# Bhavin
#
# ...
